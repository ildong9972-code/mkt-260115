# %%
# Naver > 뉴스 : API
# Yes24 
# 쉽게 크롤링 할 수 있었음!
# Jobkorea : 그동안 우리가 했던 크롤링 방식으로는 차단 or 정상적인 정보 수집 어려움
# 웹 사이트가 만들어지는 구조 이해
# html, css, js -> 언어, 스타일시트 웹 사이트 생성
# 문제발생 -> 100개 중 1개만 수정되어도 매번 서버에 데이터를 요청해야하는 비효율적인 작업 발생
# 라이브러리 검색해서 안나오면 !pip install webdriver_manager 입력 후 설치

# %% [markdown]
# 크롤링 방법
# 1) requests : 직접 받아옴
# 2) selenium : 가상의 웹 브라우저 생성해야 함
# - 브라우저는 각 드라이브 버전이 있다..

# %%
pip install webdriver_manager
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ! -> 파이썬 문법이 아님, 터미널 사용해야하는 문법
# 아나콘다 > 주피터노트북의 호환성 좋아짐 -> ! 사용하지 않아도 실행 가능

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By 
from webdriver_manager.chrome import ChromeDriverManager
from urllib import parse
import time
import pandas as pd

service = Service(ChromeDriverManager().install())
options = Options()
# options.add_argument("--headless") # 가상의 브라우저를 우리 눈에 보이지 않도록 설정
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "퍼포먼스마케터"
encoded_query = parse.quote(query)

max_pages = 6

result = []

for page in range(1, max_pages + 1) :
    url = f"https://www.jobkorea.co.kr/Search?stext={encoded_query}&Page_No={page}"
    driver.get(url)
    time.sleep(1)

    job_posts = driver.find_elements(By.CSS_SELECTOR, "div.styles_mb_space2__dk46ts4t")

    for post in job_posts : 
        try : 
            title_elem = post.find_element(By.CSS_SELECTOR, "a.Flex_display_flex__i0l0hl2.Flex_gap_space6__i0l0hl1g.Flex_align_center__i0l0hl8.styles_mb_space2__dk46ts4t")
            title = title_elem.text.strip()
            link = title_elem.get_attribute("href")
             results.append({
                "공고제목": title,
                "지원링크": link
            })
        except :
            continue
            
driver.quit()

df = pd.DataFrame(results)
df.to_excel("잡코리아_퍼포먼스마케터.xlsx", index=False)
print("잡코리아_퍼포먼스마케터.xlsx 저장완료")
# Out:
#   Cell In[22], line 41
#     results.append({
#     ^
# IndentationError: unexpected indent

# %%
from urllib import parse

query = "퍼포먼스마케터"
encoded_query = parse.quote(query)

print(encoded_query)

# %%
list01 = [1, 2, 3, 4]
str01 = "hello"

for item in list01 :
    print(item)

for item in str01 :
    print(item)
# Out:
# 1
# 2
# 3
# 4
# h
# e
# l
# l
# o

# %%
for index in range(6) :
    print(index)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
